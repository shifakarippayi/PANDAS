# %% [markdown]
# **PANDAS**

# %% [markdown]
# pandas is a python library used working with data sets.it has function for analyzing, cleaning,exploring and manipulating data.pandas allow to us analyzing big make conclusion based on the statistical theories. pandas c an clean meesy data sets,and make them readable and relevent. relevent data us very important in data science. in \pandas 1d is called series, and 2d is called frame and 3d is called panel.

# %%
import pandas as pd
data=[2,3,4,5]
s= pd.Series(data)
print(s)
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# dtype: int64

# %%
import pandas as pd
data=(2,3,4,5)
s= pd.Series(data)
print(s)
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# dtype: int64

# %%
import pandas as pd
import numpy as np
data=  np.array([[2,6,9,1],[3,4,56,1]])
s=pd.Series(data)
print(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-b7486e5fd01e> in <cell line: 4>()
#       2 import numpy as np
#       3 data=  np.array([[2,6,9,1],[3,4,56,1]])
# ----> 4 s=pd.Series(data)
#       5 print(s)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     582                 data = data.copy()
#     583         else:
# --> 584             data = sanitize_array(data, index, dtype, copy)
#     585
#     586             manager = _get_option("mode.data_manager", silent=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, allow_2d)
#     657                 subarr = maybe_infer_to_datetimelike(subarr)
#     658
# --> 659     subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     660
# ...

# %%
import pandas as pd
data=[4,5,67,32]
s=pd.Series(data)
print(s)
print(s.shape)
print(s.ndim)
print(s.dtypes)
# Out:
# 0     4
# 1     5
# 2    67
# 3    32
# dtype: int64
# (4,)
# 1
# int64

# %%
import pandas as pd
import numpy as np
data=([4,5,6,7])
s= np.Series(data,index=[100,101,10,20])
print(s)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-585fce8c1e46> in <cell line: 4>()
#       2 import numpy as np
#       3 data=([4,5,6,7])
# ----> 4 s= np.Series(data,index=[100,101,10,20])
#       5 print(s)
#
# /usr/local/lib/python3.10/dist-packages/numpy/__init__.py in __getattr__(attr)
#     331             raise RuntimeError("Tester was removed in NumPy 1.25.")
#     332
# --> 333         raise AttributeError("module {!r} has no attribute "
#     334                              "{!r}".format(__name__, attr))
#     335
#
# AttributeError: module 'numpy' has no attribute 'Series'

# %%
import pandas as pd
data={1:'sabitha',3:'misana',8:'sabi'}
s= pd.Series(data)
print(s)
# Out:
# 1    sabitha
# 3     misana
# 8       sabi
# dtype: object

# %%
import numpy as np
import pandas as pd
data={1:'sabitha',8:"misana",3:'sabi'}
s= pd.Series(data,index=[5,1,8,2,3,4])
print(s)
print(s[[3,1]])
# Out:
# 5        NaN
# 1    sabitha
# 8     misana
# 2        NaN
# 3       sabi
# 4        NaN
# dtype: object
# 3       sabi
# 1    sabitha
# dtype: object

# %%
#data frame
import numpy as np
import pandas as pd
data=[[3,4,5],[2,5,7]]
s= pd.DataFrame(data)
print(s)
# Out:
#    0  1  2
# 0  3  4  5
# 1  2  5  7

# %%
import numpy as np
import pandas as pd
data=[['sabitha',30,50,100],['misna',40,50,100]]
s= pd.DataFrame(data)
print(s)
# Out:
#          0   1   2    3
# 0  sabitha  30  50  100
# 1    misna  40  50  100

# %%
import pandas as pd
import numpy as np

#data [['shinas', 40,60,40]], ['adith',60,30,90], ['sarang', 40,50,12]]

data1 = {'Name': ['shinas', 'adith', 'sarang'], 'chem': [40,60,40], 'maths': [40,60,40], 'phy': [40,60,40]}

df = pd.DataFrame(data1)

df ['bio'] = [60,48,50]

df['total mark'] = df['chem'] + df ['maths'] + df ['phy'] +df['bio']

print(df)
# Out:
#      Name  chem  maths  phy  bio  total mark
# 0  shinas    40     40   40   60         180
# 1   adith    60     60   60   48         228
# 2  sarang    40     40   40   50         170

# %%
import pandas as pd
import numpy as np

data1 = {'Name': ['shinas', 'adith', 'sarang'], 'chem': [40,60,40], 'maths': [40,60,40], 'phy': [40,60,40]}
list1 = []

for i in df ['total mark']:
  if i<=100:
     list1.append('blw avg')

  elif i<=200:
     list1.append('avg')

  else:
     list1.append('exlnt')

print(list1)

df['status'] = list1

print(df [['Name', 'status','chem']])

print(df)
# Out:
# ['avg', 'exlnt', 'avg']
#      Name status  chem
# 0  shinas    avg    40
# 1   adith  exlnt    60
# 2  sarang    avg    40
#      Name  chem  maths  phy  bio  total mark status
# 0  shinas    40     40   40   60         180    avg
# 1   adith    60     60   60   48         228  exlnt
# 2  sarang    40     40   40   50         170    avg

# %%
import pandas as pd
import numpy as np

data1 = {'Name': ['shinas', 'adith', 'sarang'], 'chem': [40,60,40], 'maths': [40,60,40], 'phy': [40,60,40]}
list1 = []

for i in df ['total mark']:
  if i<=100:
     list1.append('blw avg')

  elif i<=200:
     list1.append('avg')

  else:
     list1.append('exlnt')

print(list1)

del df['chem']

print(df)
# Out:
# ['avg', 'exlnt', 'avg']
#      Name  maths  phy  bio  total mark status
# 0  shinas     40   40   60         180    avg
# 1   adith     60   60   48         228  exlnt
# 2  sarang     40   40   50         170    avg

# %%
import pandas as pd
import numpy as np

data1 = {'Name': ['shinas', 'adith', 'sarang'], 'chem': [40,60,40], 'maths': [40,60,40], 'phy': [40,60,40]}
list1 = []

for i in df ['total mark']:
  if i<=100:
     list1.append('blw avg')

  elif i<=200:
     list1.append('avg')

  else:
     list1.append('exlnt')

print(list1)

df['status'] = list1

print(df)
# Out:
# ['avg', 'exlnt', 'avg']
#      Name  maths  phy  bio  total mark status
# 0  shinas     40   40   60         180    avg
# 1   adith     60   60   48         228  exlnt
# 2  sarang     40   40   50         170    avg

# %%
import pandas as pd

import numpy as np

data1={'name': ['shinas', 'adith', 'sarang'], 'chem': [40,60,40], 'maths': [40,60,40], 'phy': [40,60,46]}

s=pd.DataFrame (data1)


s['bio']=[60,48,50]

s['total']=s['chem']+s['maths']+s['phy']+s['bio']

list1=[]

for i in s['total']:

     if i<=100:
       list1.append('blw avg')
     elif i<=200:
       list1.append('avg')
     else:
      list1.append('exclnt')

#print(list1)

s['status']=list1

print(s)

del s['chem']

s=s.drop('phy', axis=1) #want to specify axis

s.pop('maths')

print(s)

print(s.ndim)

print(s.shape)

print(s.size)
print(s.columns)

print(s['status'].unique())

print(s['bio'].unique())

print(s['status'].value_counts())

print(s)
# Out:
#      name  chem  maths  phy  bio  total  status
# 0  shinas    40     40   40   60    180     avg
# 1   adith    60     60   60   48    228  exclnt
# 2  sarang    40     40   46   50    176     avg
#      name  bio  total  status
# 0  shinas   60    180     avg
# 1   adith   48    228  exclnt
# 2  sarang   50    176     avg
# 2
# (3, 4)
# 12
# Index(['name', 'bio', 'total', 'status'], dtype='object')
# ['avg' 'exclnt']
# [60 48 50]
# status
# avg       2
# exclnt    1
# Name: count, dtype: int64
#      name  bio  total  status
# 0  shinas   60    180     avg
# 1   adith   48    228  exclnt
# 2  sarang   50    176     avg

# %%
print(df)
# Out:
#      Name  bio  total mark status
# 0  shinas   60         180    avg
# 1   adith   48         228  exlnt
# 2  sarang   50         170    avg

# %%
print(df.head())
# Out:
#      Name  bio  total mark status
# 0  shinas   60         180    avg
# 1   adith   48         228  exlnt
# 2  sarang   50         170    avg

# %%
print(df.head(2))
# Out:
#      Name  bio  total mark status
# 0  shinas   60         180    avg
# 1   adith   48         228  exlnt

# %%
print(df.tail(2))
# Out:
#      Name  bio  total mark status
# 1   adith   48         228  exlnt
# 2  sarang   50         170    avg

# %%
print(df.describe())
# Out:
#              bio  total mark
# count   3.000000    3.000000
# mean   52.666667  192.666667
# std     6.429101   31.005376
# min    48.000000  170.000000
# 25%    49.000000  175.000000
# 50%    50.000000  180.000000
# 75%    55.000000  204.000000
# max    60.000000  228.000000

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        3 non-null      object
#  1   bio         3 non-null      int64
#  2   total mark  3 non-null      int64
#  3   status      3 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 224.0+ bytes
# None

# %%
print(df['bio'].sum())
# Out:
# 158

# %%
print(df.sum(1)) #row wise
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-343358c3c291> in <cell line: 1>()
# ----> 1 print(df.sum(1))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11668         **kwargs,
#   11669     ):
# > 11670         result = super().sum(axis, skipna, numeric_only, min_count, **kwargs)
#   11671         return result.__finalize__(self, method="sum")
#   11672
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12504         **kwargs,
#   12505     ):
# > 12506         return self._min_count_stat_function(
#   12507             "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   12508         )
#
# ...

# %%
print(df.sum(0)) #column wise
# Out:
# Name          shinasadithsarang
# bio                         158
# total mark                  578
# status              avgexlntavg
# dtype: object

# %%
print(df['bio'].mean())
# Out:
# 52.666666666666664

# %%
print(df.describe())
# Out:
#              bio  total mark
# count   3.000000    3.000000
# mean   52.666667  192.666667
# std     6.429101   31.005376
# min    48.000000  170.000000
# 25%    49.000000  175.000000
# 50%    50.000000  180.000000
# 75%    55.000000  204.000000
# max    60.000000  228.000000
